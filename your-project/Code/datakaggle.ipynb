# %%
import pandas as pd

# %%
pd.read_csv("../../../418397_806637_bundle_archive/country_names_2_digit_codes.csv")
# Out:
#                   Name Code
# 0          Afghanistan   AF
# 1       Ã…land Islands   AX
# 2              Albania   AL
# 3              Algeria   DZ
# 4       American Samoa   AS
# ..                 ...  ...
# 244  Wallis and Futuna   WF
# 245     Western Sahara   EH
# 246              Yemen   YE
# 247             Zambia   ZM
# 248           Zimbabwe   ZW
#
# [249 rows x 2 columns]

# %%
pd.read_csv("../../../418397_806637_bundle_archive/currency_exchange.csv")
# Out:
#     Code                                       Country  \
# 0    AED                    United Arab Emirates (The)
# 1    AFN                                   Afghanistan
# 2    ALL                                       Albania
# 3    AMD                                       Armenia
# 4    ANG                                       Curaçao
# ..   ...                                           ...
# 263  ZMW                                        Zambia
# 264  ZWL                                      Zimbabwe
# 265  NaN                                    Antarctica
# 266  NaN                           Palestine, State Of
# 267  NaN  South Georgia And The South Sandwich Islands
#
#                           Currency  Number  ExchangeRate
# 0                       UAE Dirham   784.0      3.672779
# 1                          Afghani   971.0     78.250197
# 2                              Lek     8.0    111.702860
# 3                    Armenian Dram    51.0    477.169811
# ...

# %%
glassdoor = pd.read_csv("../../../418397_806637_bundle_archive/glassdoor.csv")
glassdoor
# Out:
#         benefits.benefitRatingDecimal  benefits.comments  benefits.highlights  \
# 0                            0.000000             2801.0               2801.0
# 1                            4.000000             2802.0               2802.0
# 2                            0.000000             2803.0               2803.0
# 3                            0.000000             2804.0               2804.0
# 4                            0.000000             2805.0               2805.0
# ...                               ...                ...                  ...
# 165285                       0.000000            58396.0              58396.0
# 165286                       3.941176            58397.0              58397.0
# 165287                       0.000000            58398.0              58398.0
# 165288                       0.000000            58399.0              58399.0
# 165289                       0.000000            58400.0              58400.0
#
# ...

# %%
pd.read_csv("../../../418397_806637_bundle_archive/glassdoor_benefits_comments.csv")
# Out:
#            id  index benefits.comments.val.city  \
# 0         401    NaN                        NaN
# 1         402    NaN                        NaN
# 2         403    NaN                        NaN
# 3         404    NaN                        NaN
# 4         405    NaN                        NaN
# ...       ...    ...                        ...
# 271431  33598    0.0                     London
# 271432  33599    0.0                    Cwmbran
# 271433  33599    1.0                     Slough
# 271434  33599    2.0                    Cwmbran
# 271435  33600    NaN                        NaN
#
#                             benefits.comments.val.comment  \
# 0                                                     NaN
# 1                                                     NaN
# 2                                                     NaN
# 3                                                     NaN
# 4                                                     NaN
# ...

# %%
pd.read_csv("../../../418397_806637_bundle_archive/glassdoor_photos.csv")
# Out:
#            id  index                   photos.val.caption  photos.val.photoId  \
# 0       26411      0                            Mango day            10772510
# 1       26411      1              We REALLY like cupcakes            17246228
# 2       26411      2                          Heli-skiing            17223544
# 3       26411      3               Rocking out in Karachi            17223536
# 4       26411      4                         New offices!            17223528
# ...       ...    ...                                  ...                 ...
# 636154   1917      2  Company Picnic - Water Balloon Toss            13465159
# 636155   1917      3  Company Picnic - Water Balloon Toss            13465151
# 636156   1917      4                       Company Picnic            13465143
# 636157   1917      5      company Picnic - Glass Painting            13465135
# 636158   1917      6                       Company Picnic            13465073
#
#         photos.val.photoId2x  \
# ...
